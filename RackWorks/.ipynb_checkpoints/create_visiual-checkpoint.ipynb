# %%
import openpyxl
from openpyxl.styles import PatternFill, Border, Side, Alignment, Font
import os

def generate_visual(distribution, loc):
    # Delete the file if it already exists
    filename = "rack_layout_top_down.xlsx"
    if os.path.exists(filename):
        os.remove(filename)
        print(f"Existing file '{filename}' deleted.")
    node_positions = distribution['stable_placement']
    # Create a new workbook
    wb = openpyxl.Workbook()
    ws = wb.active
    ws.title = "Rack Layout"

    # Set column widths
    ws.column_dimensions['A'].width = 25  # Rack Position
    ws.column_dimensions['B'].width = 25  # Device
    ws.column_dimensions['C'].width = 15  # Wattage (W)
    ws.column_dimensions['D'].width = 15  # Weight (kg)

    # Define styles
    header_font = Font(bold=True)
    border = Border(left=Side(style='thin'), right=Side(style='thin'), 
                    top=Side(style='thin'), bottom=Side(style='thin'))
    center_aligned = Alignment(horizontal='center', vertical='center')
    total_font = Font(bold=True)
    total_fill = PatternFill(start_color='FFFF00', end_color='FFFF00', fill_type='solid')  # Yellow background

    # Define colors for different node types
    color_map = {
        'compute_nodes': 'FF9999',  # Light red
        'GPU_nodes': '99CCFF',      # Light blue
        'LAN': '99FF99',            # Light green
    }

    # Write headers (added Wattage and Weight columns)
    headers = ["Rack Position", "Device", "Wattage (W)", "Weight (kg)"]
    for col, header in enumerate(headers, start=1):
        cell = ws.cell(row=1, column=col, value=header)
        cell.font = header_font
        cell.border = border
        cell.alignment = center_aligned

    # Create a dictionary to track occupied positions
    occupied_positions = {}
    position_numbers = {}  # To store the actual rack position numbers
    total_wattage = 0
    total_weight = 0

    # First pass: Identify all positions and their heights
    for device, posy in node_positions.items():
        if 'LAN_' in device:
            # Handle LAN devices
            lan_parts = '_'.join(device.split('_')[:-1]).split('__')
            lan_type = lan_parts[0]
            switch_model = lan_parts[1]
            height = 2  # Default height for switches
            wattage = 0
            weight = 0
            #print('sssss',device,switch_model)
            for switch in LANs[lan_type]['switch']:
                if switch['model'] == switch_model:
                    height = switch['height']
                    wattage = switch['wattage']
                    weight = switch['weight']
                    break
            
            pos = posy + height -1 
            actual_pos = 43 - pos  # Convert to top-down numbering
            occupied_positions[actual_pos] = {
                'device': device,
                'type': 'LAN Switch',
                'height': height,
                'color': color_map.get('LAN', 'FFFFFF'),
                'original_pos': pos,
                'wattage': wattage,
                'weight': weight
            }
            total_wattage += wattage
            total_weight += weight
        else:
            # Handle other nodes
            node_type = device.split('_')[0] + '_' + device.split('_')[1]
            height = colors_info[node_type]['height']
            wattage = colors_info[node_type]['wattage']
            weight = colors_info[node_type]['weight']
            pos = posy + height -1 
            actual_pos = 43 - pos  # Convert to top-down numbering
            occupied_positions[actual_pos] = {
                'device': device,
                'type': node_type.replace('_', ' ').title(),
                'height': height,
                'color': color_map.get(node_type, 'FFFFFF'),
                'original_pos': pos,
                'wattage': wattage,
                'weight': weight
            }
            total_wattage += wattage
            total_weight += weight

    # Calculate physical position numbers accounting for device heights
    physical_positions = {}
    current_physical_pos = 42
    occupied_label = dict()
    for rack_pos in range(1,43):
        if rack_pos in occupied_positions:
            device_info = occupied_positions[rack_pos]
            height = device_info['height']
            
            # Assign the physical position to the top of the device
            physical_positions[rack_pos] = current_physical_pos
            occupied_label[rack_pos] = str(current_physical_pos-height+1)+'-'+str(current_physical_pos)
            # Mark all occupied positions by this device
            for i in range(1, height):
                physical_positions[rack_pos + i] = None  # Mark as occupied
            
            # Decrement the physical position counter by 1 (not by height)
            current_physical_pos -= height
        else:
            physical_positions[rack_pos] = current_physical_pos
            current_physical_pos -= 1

    # Second pass: Write data to cells and handle merging
    current_row = 2
    for rack_pos in range(1, 43):
        # Skip if this is part of a multi-slot device (not the top)
        if rack_pos in occupied_positions and physical_positions[rack_pos] is None:
            current_row += 1
            continue
            
        # Get the physical position number
        if rack_pos in physical_positions:
            position_number = str(physical_positions[rack_pos])
            position_number = occupied_label.get(rack_pos,str(physical_positions[rack_pos]))
            if position_number.startswith('-') or position_number.startswith('0'):
                position_number = None
            
        else:
            position_number = None

        # Write rack position number
        if position_number is not None:
            ws.cell(row=current_row, column=1, value=position_number)
            ws.cell(row=current_row, column=1).border = border
            ws.cell(row=current_row, column=1).alignment = center_aligned

        if rack_pos in occupied_positions and physical_positions[rack_pos] is not None and physical_positions[rack_pos] > 0:
            device_info = occupied_positions[rack_pos]
            height = device_info['height']
           
            # Write device info
            ws.cell(row=current_row, column=2, value=device_info['device'])
            # Write wattage and weight
            ws.cell(row=current_row, column=3, value=device_info['wattage'])
            ws.cell(row=current_row, column=4, value=device_info['weight'])
            
            # Apply styling to all columns
            fill = PatternFill(start_color=device_info['color'], end_color=device_info['color'], fill_type='solid')
            for col in range(1, 5):  # Now includes columns A-D
                ws.cell(row=current_row, column=col).fill = fill
                ws.cell(row=current_row, column=col).border = border
                ws.cell(row=current_row, column=col).alignment = center_aligned

            # Merge cells if height > 1
            if height > 1:
                for col in range(1, 5):  # Merge all columns (A-D)
                    ws.merge_cells(start_row=current_row, start_column=col,
                                 end_row=current_row + height - 1, end_column=col)
                    # Set alignment for the merged cell
                    for row in range(current_row, current_row + height):
                        ws.cell(row=row, column=col).alignment = center_aligned
                
                # Skip the merged rows in the main loop
                current_row += height - 1
        else:
            # Empty position
            if physical_positions[rack_pos] > 0:
                for col in range(2, 5):  # Clear columns B-D for empty positions
                    ws.cell(row=current_row, column=col, value="")
                    ws.cell(row=current_row, column=col).border = border
        if physical_positions[rack_pos] > 0:
            current_row += 1

    # Add total row at the bottom
    total_row = current_row + 1  # Add an empty row before the total
    ws.cell(row=total_row, column=1, value="TOTAL").font = total_font
    ws.cell(row=total_row, column=2, value="").font = total_font
    ws.cell(row=total_row, column=3, value=total_wattage).font = total_font
    ws.cell(row=total_row, column=4, value=total_weight).font = total_font
    
    # Apply styling to total row
    for col in range(1, 5):
        ws.cell(row=total_row, column=col).border = border
        ws.cell(row=total_row, column=col).fill = total_fill
        ws.cell(row=total_row, column=col).alignment = center_aligned

    # Save the workbook
    wb.save(filename)
    print(f"Excel file '{filename}' has been created with positions from 42 at top to 1 at bottom.")

# %%
def iterate_on_racks():
    for i in distributions_info:
        generate_visual(distributions_info[i],i)
        return

# %%
import pickle
from collections import Counter
from math import floor
def global_main():
    global colors_info, LANs, Cables, max_box_wattage, max_box_height,  rack_height_u , rack_weight_kg, rack_width_mm, \
            rack_depth_mm, u_height_mm, rack_height_mm, rack_height_u, rack_cg_height_mm, unit_to_cm, u_height_mm, \
            device_to_rackside, racktop_to_ceiling, rack_to_rack, Rack_rows, Rack_rows, distributions_info
    


    with open('Latest_Racks_info.pkl', 'rb') as f:
        colors_info, LANs, Cables, Rack_rows, distributions_info = pickle.load(f)
    
    
    max_box_wattage = 16000
    max_box_height = rack_height_u = 42
    rack_weight_kg = 114.55
    rack_width_mm = 750
    rack_depth_mm = 1200
    u_height_mm = 44.45
    rack_height_mm = rack_height_u * u_height_mm
    rack_cg_height_mm = rack_height_mm / 2
    global_rack_signature = dict()
    unit_to_cm = u_height_mm /10
    # the following are in units
    device_to_rackside = 6.75
    racktop_to_ceiling = 4.5 # assumed 20cm
    rack_to_rack = 4.5 # assumed from side to the adjacent side no spacing
    # adding to the Cables the maximum stretch
    for switch in Cables:
        for cable in Cables[switch]:
            cable['in_rack_stretch'] = floor((cable['length']*100/unit_to_cm) - (2* device_to_rackside))
            
            
if __name__ == "__main__":
    global_main()
    iterate_on_racks()
# Out:
# Existing file 'rack_layout_top_down.xlsx' deleted.
# Excel file 'rack_layout_top_down.xlsx' has been created with positions from 42 at top to 1 at bottom.
